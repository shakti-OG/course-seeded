# %% [markdown]
# <a href="https://colab.research.google.com/github/shakti-OG/course-seeded/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # COURSE-SEEDED

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !mkdir -p cpp_project

# %%
# %cd cpp_project
# Out:
# /content/drive/MyDrive/cpp_project

# %%
# %%writefile main.cpp
#
# //code goes over here for C++
# #include <iostream>
# using namespace std;
# int main(){
#   cout << "Hello\n";
# }
# Out:
# Overwriting main.cpp

# %%
# !ls
# Out:
# main.cpp

# %%
# !g++ main.cpp -o main

# %%
# !ls
# Out:
# main  main.cpp

# %%
# !./main
# Out:
# Hello
